# %% [markdown]
# # Image Analysis
# ## Practice 1
# ## Alcaraz Fraga Ricardo

# %% [markdown]
# Images are really important since they have existed, they allow us to save information in a very unique way, in a graphic way, in a way we are familiarized since we were born.
# With the great boom of Machine Learning, thanks to advances in both hardware and algorithms, images serve a really important task, we can extract a lot of information from them and we can make predictions on new images based on what we know about old images.
# This whole notebook is focused on Preprocessing, the way we prepare images for models to make better predictions.

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
from PIL import Image

# %matplotlib inline

# %% [markdown]
# ### Using PIL and matplotlib to display images

# %%
# Getting the images in the actual folder and asking the user which one to use

def ls(ruta = '.'):
    return [arch for arch in listdir(ruta) if isfile(join(ruta, arch))]

print('Images in the actual folder: ', ls())

print('Type the name of the image you want to work with: ')
pic_name = input()
# Out:
# Images in the actual folder:  ['grayscale_image.jpg', 'coins.png', 'IA_P1__2018630891_.ipynb', 'header_escom26.jpg', 'peppers.png']
# Type the name of the image you want to work with:
# header_escom26.jpg

# %%
pic = Image.open(pic_name) #Open the image
pic #Diplays the image in the notebook
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x540 at 0x7F3331601750>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# ### Transforming the image to an array

# %%
pic_arr = np.asarray(pic)
pic_arr.shape
# Out:
# (540, 960, 3)

# %%
pic_arr.shape
# Out:
# (540, 960, 3)

# %%
pic_arr
# Out:
# array([[[251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        [[251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251],
#         ...,
#         [229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229]],
#
#        ...,
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241],
#         ...,
#         [251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241],
#         ...,
#         [251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251]],
#
#        [[241, 241, 241],
#         [241, 241, 241],
#         [241, 241, 241],
#         ...,
#         [251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251]]], dtype=uint8)

# %% [markdown]
# ### Showing the image with matplotlib

# %%
plt.imshow(pic_arr)

# %%
pic_arr.shape
# Out:
# (540, 960, 3)

# %% [markdown]
# ### Defining a function to isolate the values from an image with 3 channels (RGB)

# %%
def obtain_values_3d(image, channel):
    pic_values = image.copy()
    
    if(channel == 'red'):
        pic_values[:,:,1]=0
        pic_values[:,:,2]=0
    
    elif(channel == 'green'):
        pic_values[:,:,0]=0
        pic_values[:,:,2]=0
    
    elif(channel == 'blue'):
        pic_values[:,:,0]=0
        pic_values[:,:,1]=0
    
    else:
        print('Invalid channel')
    
    return pic_values

# %% [markdown]
# ### Visualizing the channels

# %%
# If the image has 3 channels
if(len(pic_arr.shape) == 3):
    pic_red = obtain_values_3d(pic_arr, 'red')
    pic_green = obtain_values_3d(pic_arr, 'green')
    pic_blue = obtain_values_3d(pic_arr, 'blue')
    
    fig, axs = plt.subplots(1, 3, figsize=(20,5), sharey=True)
    axs[0].imshow(pic_red,cmap='gray')
    axs[0].set_xlabel("red")
    axs[1].imshow(pic_green,cmap='gray')
    axs[1].set_xlabel("green")
    axs[2].imshow(pic_blue,cmap='gray')
    axs[2].set_xlabel("blue")
    fig.suptitle('Image channels')
    
else:
    print('No rgb channels')

# %% [markdown]
# ### Reshaping the arrays

# %%
def reshape_3darray(array, channel):
    if(channel == 'red'):
        pic_1 = array[:,:,0]
        pic_2 = pic_1.flatten()
    
    elif(channel == 'green'):
        pic_1 = array[:,:,1]
        pic_2 = pic_1.flatten()
    
    elif(channel == 'blue'):
        pic_1 = array[:,:,2]
        pic_2 = pic_1.flatten()
    
    else:
        print("Invalid channel")
    
    return pic_2

# %% [markdown]
# Histograms are a great to visually analyze images to get a better idea of how are they composed. In the following algorithm, we are going to calculate the histograms of the three channels in the rgb format.
# Here are the steps of the algorithm:
#
# * Flatten the arrays
# * Create a 256 values array filled with zeros
# * Go through the array and we read the value in which we are standing
# * The value we read is an index, minus one, we head that element in the array and we add 1
# * We repeat the same steps for the other two channels

# %%
if(len(pic_arr.shape) == 3):
    pic_r = reshape_3darray(pic_arr, 'red')
    pic_g = reshape_3darray(pic_arr, 'green')
    pic_b = reshape_3darray(pic_arr, 'blue')
    
    #Get the height and the width
    height=pic_arr.shape[0]
    width=pic_arr.shape[1]

    #RED CHANNEL
    hist_red=np.zeros(256)

    ##CODE TO CALCULATE RED CHANNEL HISTOGRAM
    for i in range(0, len(pic_r)):
        a = pic_r[i] - 1

        hist_red[a] = hist_red[a] + 1

    #GREEN CHANNEL
    hist_green=np.zeros(256)
    
    ##CODE TO CALCULATE GREEN CHANNEL HISTOGRAM
    for i in range(0, len(pic_g)):
        a = pic_g[i] - 1

        hist_green[a] = hist_green[a] + 1


    #BLUE CHANNEL
    hist_blue=np.zeros(256)

    ##CODE TO CALCULATE BLUE CHANNEL HISTOGRAM
    for i in range(0, len(pic_b)):
        a = pic_b[i] - 1

        hist_blue[a] = hist_blue[a] + 1

    fig, axs = plt.subplots(1, 3, figsize=(20,5), sharey=True)
    axs[0].plot(hist_red,color = "r")
    axs[0].set_xlabel("red")
    axs[1].plot(hist_green,color = "g")
    axs[1].set_xlabel("green")
    axs[2].plot(hist_blue,color = "b")
    axs[2].set_xlabel("blue")
    fig.suptitle('Histogram channels')

else:
    print('No rgb channels')

# %% [markdown]
# ### Calculating the histograms in the same step

# %%
if(len(pic_arr.shape) == 3):

    histogram=np.zeros((3,256))


    ##CODE TO CALCULATE RED, BLUE AND GREEN CHANNEL HISTOGRAM AT THE SAME TIME

    for channel in range(0, 3):
        for i in range(0, height):
            for j in range(0, width):
                a = pic_arr[i][j][channel] - 1
                histogram[channel][a] = histogram[channel][a] + 1

    plt.plot(histogram[0],color = "r")
    plt.plot(histogram[1],color = "g")
    plt.plot(histogram[2],color = "b")
    plt.show()

else:
    print('No rgb channels')

# %% [markdown]
# ### Thresholding the image

# %%
if(len(pic_arr.shape) == 3):

    T = 120 #The Threshold

    pic_arr2=pic_arr.copy()

    for channel in range(0,3):   #FOR EVERY CHANNEL (R,G,B)
        for i in range(0,height):   #FOR EVERY ROW   
            for j in range(0,width):   #FOR EVERY COLUMN
                if(pic_arr2[i][j][channel] < T): #IF THE PIXELS VALUE IS LESS THAN THE THRESHOLD T
                    pic_arr2[i][j][channel] = 0   #SET TO 0
                else:
                    pic_arr2[i][j][channel] = 255 #SET TO 255

    plt.imshow(pic_arr2)

# %% [markdown]
# ### Transforming an rgb image to a grayscale image

# %% [markdown]
# A sofisticated way

# %%
if(len(pic_arr.shape) == 3):
    pic_arr3 = pic_arr.copy()

    for i in range(0, height):
        for j in range(0, width):
        
            new_pix = 0.21 * float(pic_arr3[i][j][0]) + 0.72 * float(pic_arr3[i][j][1]) + 0.07 * float(pic_arr3[i][j][2])
            new_pix = int(new_pix)
        
            pic_arr3[i][j][0] = new_pix
            pic_arr3[i][j][1] = new_pix
            pic_arr3[i][j][2] = new_pix

# %%
plt.imshow(pic_arr3)

# %% [markdown]
# A not so sofisticated way

# %%
if(len(pic_arr.shape) == 3):
    pic_arr4 = pic_arr.copy()

    for i in range(0, height):
        for j in range(0, width):
        
            new_pix = (pic_arr4[i][j][0] + pic_arr4[i][j][1] + pic_arr4[i][j][2]) / 3        
        
            pic_arr4[i][j][0] = new_pix
            pic_arr4[i][j][1] = new_pix
            pic_arr4[i][j][2] = new_pix
# Out:
# /home/ricardo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in ubyte_scalars
#   import sys

# %%
plt.imshow(pic_arr4)

# %% [markdown]
# A totally not sofisticated way

# %%
pic_arr5 = pic_arr.copy()

#(max(R, G, B) + min(R, G, B)) / 2

if(len(pic_arr.shape) == 3):
    for i in range(0, height):
        for j in range(0, width):
        
            new_pix = (max(pic_arr5[i][j][0], pic_arr5[i][j][1], pic_arr5[i][j][2]) + min(pic_arr5[i][j][0], pic_arr5[i][j][1], pic_arr5[i][j][2]))
        
            pic_arr5[i][j][0] = new_pix
            pic_arr5[i][j][1] = new_pix
            pic_arr5[i][j][2] = new_pix
# Out:
# /home/ricardo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in ubyte_scalars
#   if __name__ == '__main__':

# %%
plt.imshow(pic_arr5)
